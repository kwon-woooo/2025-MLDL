# %%
import seaborn as sns
titanic =sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #1. 수치형 데이터 시각화

# %% [markdown]
# ### histplot

# %%
sns.histplot(data=titanic,x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic,x='age',bins=10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic,x='age',hue='alive')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic,x='age',hue='alive',multiple='stack')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### kdeplot
# - 히스토그램을 매끄러운 곡선으로 연결한 그래프

# %%
sns.kdeplot(data=titanic, x='age')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=titanic, x='age',hue='alive',multiple='stack')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# ###displot

# %%
sns.displot(data=titanic,x='age')

# %%
sns.displot(data=titanic,x='age',kind='kde')

# %%
sns.displot(data=titanic,x='age',kde=True)

# %% [markdown]
# ### rugplot

# %%
sns.kdeplot(data=titanic, x='age')
sns.rugplot(data=titanic, x='age')
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# #2. 범주형 데이터 시각화

# %% [markdown]
# ### barplot

# %%
sns.barplot(x="class",y="fare",data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# - 원래는 평균값을 나타내지만 estimator= (np.median,np.max,np.min) 등을 통해 바꿀 수 있다.

# %% [markdown]
# ### pointplot

# %%
sns.pointplot(x="class",y="fare",data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %% [markdown]
# ### boxplot

# %%
sns.boxplot(x="class",y="age",data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# ### violinplot

# %%
sns.violinplot(x="class",y="age",data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x="class",y="age",hue="sex",data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x="class",y="age",hue="sex",data=titanic,split=True)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %% [markdown]
# ### countplot

# %%
sns.countplot(x="class", data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.countplot(y="class", data=titanic)
# Out:
# <Axes: xlabel='count', ylabel='class'>

# %% [markdown]
# ### pieplot

# %%
import matplotlib.pyplot as plt

x=[20,60,30]
labels= ['A','B','c']

plt.pie(x=x, labels=labels, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7afc461295d0>,
#   <matplotlib.patches.Wedge at 0x7afc46039010>,
#   <matplotlib.patches.Wedge at 0x7afc4603b590>],
#  [Text(0.9253788637715525, 0.5947049339671486, 'A'),
#   Text(-1.0554423291909099, 0.30990561426354835, 'B'),
#   Text(0.7203468067429806, -0.831324532306843, 'c')],
#  [Text(0.5047521075117558, 0.3243845094366265, '18.2%'),
#   Text(-0.5756958159223144, 0.16903942596193544, '54.5%'),
#   Text(0.39291644004162574, -0.45344974489464157, '27.3%')])

# %% [markdown]
# #3. 데이터 관계 시각화

# %%
import seaborn as sns
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# ### 히트맵

# %%
flights_pivot = flights.pivot(index = 'month',
                              columns='year',
                              values='passengers')
flights_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
sns.heatmap(data=flights_pivot)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# ### lineplot

# %%
sns.lineplot(x="year",y="passengers",data = flights)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %% [markdown]
# ### scatterplot(산점도)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x= "total_bill", y= "tip", data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x= "total_bill", y= "tip", hue = "time", data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### regplot(회귀선을 포함한 산점도)

# %%
sns.regplot(x= "total_bill", y= "tip", data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x= "total_bill", y= "tip", ci=99, data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
